# %% [markdown]
# # IPL Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("matches.csv")
df = pd.DataFrame(data)
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# Q1. Count the total number of matches conducted in 2008.

# %%
(df['season'] == 2018).sum()
# Out:
# 60

# %% [markdown]
# Q2. Find the cities where the maximum and minimum number of matches were
# conducted.

# %%
print("Largest is: ", df['city'].value_counts().nlargest(1))
print("Smallest is: ", df['city'].value_counts().nsmallest(1))
# Out:
# Largest is:  Mumbai    101
# Name: city, dtype: int64
# Smallest is:  Bloemfontein    2
# Name: city, dtype: int64

# %%
df[df['city'] == "Bloemfontein"]
# Out:
#       id  season          city        date             team1  \
# 160  161    2009  Bloemfontein  2009-05-15  Delhi Daredevils
# 164  165    2009  Bloemfontein  2009-05-17  Delhi Daredevils
#
#                 team2       toss_winner toss_decision  result  dl_applied  \
# 160   Kings XI Punjab   Kings XI Punjab         field  normal           0
# 164  Rajasthan Royals  Delhi Daredevils           bat  normal           0
#
#                winner  win_by_runs  win_by_wickets player_of_match  \
# 160   Kings XI Punjab            0               6           B Lee
# 164  Delhi Daredevils           14               0  AB de Villiers
#
#                venue          umpire1    umpire2 umpire3
# 160  OUTsurance Oval  HDPK Dharmasena  IL Howell     NaN
# 164  OUTsurance Oval        SS Hazare  IL Howell     NaN

# %% [markdown]
# Q3. Find total count of matches city-wise.

# %%
print(df['city'].value_counts())
df['city'].value_counts().sum()
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: city, dtype: int64
# 749

# %% [markdown]
# Q4. Tally the toss decisions each team has taken.

# %%
uniques = df['toss_winner'].unique()
for i in uniques:
    print(df[df['toss_winner'] == i][['toss_winner', 'toss_decision']].value_counts().to_string())
# Out:
# toss_winner                  toss_decision
# Royal Challengers Bangalore  field            61
#                              bat              20
# toss_winner             toss_decision
# Rising Pune Supergiant  field            6
# toss_winner            toss_decision
# Kolkata Knight Riders  field            62
#                        bat              30
# toss_winner      toss_decision
# Kings XI Punjab  field            55
#                  bat              26
# toss_winner          toss_decision
# Sunrisers Hyderabad  field            26
#                      bat              20
# toss_winner     toss_decision
# Mumbai Indians  field            54
#                 bat              44
# toss_winner    toss_decision
# Gujarat Lions  field            14
#                bat               1
# toss_winner       toss_decision
# Delhi Daredevils  field            51
#                   bat              29
# toss_winner          toss_decision
# ...

# %% [markdown]
# Q5. Count the total number of normal and tied matches.

# %%
df['result'].value_counts()[['normal', 'tie']]
# Out:
# normal    743
# tie         9
# Name: result, dtype: int64

# %% [markdown]
# Q6. Find the teams where the result was a tie

# %%
df[df["result"] == "tie"][["team1", "team2"]]
# Out:
#                            team1                        team2
# 33                 Gujarat Lions               Mumbai Indians
# 125             Rajasthan Royals        Kolkata Knight Riders
# 189              Kings XI Punjab          Chennai Super Kings
# 387  Royal Challengers Bangalore          Sunrisers Hyderabad
# 400             Delhi Daredevils  Royal Challengers Bangalore
# 475             Rajasthan Royals        Kolkata Knight Riders
# 535             Rajasthan Royals              Kings XI Punjab
# 705        Kolkata Knight Riders               Delhi Capitals
# 746               Mumbai Indians          Sunrisers Hyderabad

# %% [markdown]
# Q7. Find the team which won the match by the highest and lowest number of
# runs.

# %%
display(df[df['win_by_runs'] == df['win_by_runs'].max()][['winner', 'win_by_runs']])
display(df[df['win_by_runs'] == 1][['winner', 'win_by_runs']])
# Out:
#             winner  win_by_runs
# 43  Mumbai Indians          146
#                           winner  win_by_runs
# 58                Mumbai Indians            1
# 105              Kings XI Punjab            1
# 163              Kings XI Punjab            1
# 344             Delhi Daredevils            1
# 350               Mumbai Indians            1
# 518          Chennai Super Kings            1
# 598                Gujarat Lions            1
# 614  Royal Challengers Bangalore            1
# 734  Royal Challengers Bangalore            1
# 755               Mumbai Indians            1

# %% [markdown]
# Q8. Calculate mean, median and standard deviation of ‘win_by_runs’

# %%
print("Mean of win_by_runs is: ", df['win_by_runs'].mean())
print("Mean of win_by_runs is: ", df['win_by_runs'].median())
print("Median of win_by_runs is: ", df['win_by_runs'].std())
# Out:
# Mean of win_by_runs is:  13.283068783068783
# Mean of win_by_runs is:  0.0
# Median of win_by_runs is:  23.47114399366638

# %% [markdown]
# Q9. Find the venue where the team won by the highest and lowest number of runs.

# %%
print("Venue (highest runs): ", df[df['win_by_runs'] == df['win_by_runs'].max()]['venue'])
display("Venue lowest runs: ", df[df['win_by_runs'] == 1]['venue'])
# Out:
# Venue (highest runs):  43    Feroz Shah Kotla
# Name: venue, dtype: object
# 'Venue lowest runs: '
# 58             Rajiv Gandhi International Stadium, Uppal
# 105                                     Wankhede Stadium
# 163                                New Wanderers Stadium
# 344                                     Feroz Shah Kotla
# 350                           Subrata Roy Sahara Stadium
# 518                      MA Chidambaram Stadium, Chepauk
# 598                                     Feroz Shah Kotla
# 614    Punjab Cricket Association IS Bindra Stadium, ...
# 734                               M. Chinnaswamy Stadium
# 755                   Rajiv Gandhi Intl. Cricket Stadium
# Name: venue, dtype: object

# %% [markdown]
# Q10. Find the players who have won ‘Player of the Match’ more than 3 times.

# %%
pom = dict(df['player_of_match'].value_counts())
for i in list(pom.keys()):
    if pom[i] > 3:
        print(f"{i}\t{pom[i]}")
# Out:
# CH Gayle	21
# AB de Villiers	20
# RG Sharma	17
# MS Dhoni	17
# DA Warner	17
# YK Pathan	16
# SR Watson	15
# SK Raina	14
# G Gambhir	13
# MEK Hussey	12
# AM Rahane	12
# V Kohli	12
# V Sehwag	11
# DR Smith	11
# AD Russell	11
# A Mishra	11
# JH Kallis	10
# KA Pollard	10
# SE Marsh	9
# AT Rayudu	9
# SP Narine	9
# Harbhajan Singh	8
# SR Tendulkar	8
# RA Jadeja	8
# UT Yadav	8
# Rashid Khan	7
# RV Uthappa	7
# AC Gilchrist	7
# M Vijay	6
# RR Pant	6
# S Dhawan	6
# SL Malinga	6
# A Nehra	6
# BJ Hodge	6
# HH Pandya	6
# SC Ganguly	5
# SPD Smith	5
# PA Patel	5
# KC Sangakkara	5
# DPMD Jayawardene	5
# BB McCullum	5
# JP Faulkner	5
# AJ Finch	5
# DW Steyn	5
# Yuvraj Singh	5
# SV Samson	5
# GJ Maxwell	5
# JJ Bumrah	5
# Sandeep Sharma	5
# JD Unadkat	5
# JC Buttler	5
# B Kumar	5
# KL Rahul	4
# KD Karthik	4
# JP Duminy	4
# MK Pandey	4
# NM Coulter-Nile	4
# AR Patel	4
# N Rana	4
# F du Plessis	4
# SK Warne	4
# CA Lynn	4
# SS Iyer	4
# ML Hayden	4
# KH Pandya	4

# %% [markdown]
# Q11. Find all deliveries where the batsman scored a six.

# %%
df2 = pd.read_csv("deliveries.csv")
df2.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
df2[df2['batsman_runs'] == 6]
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 10             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 47             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 75             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 89             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 91             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 178987     11415       2  Chennai Super Kings               Mumbai Indians
# 179048     11415       2  Chennai Super Kings               Mumbai Indians
# 179061     11415       2  Chennai Super Kings               Mumbai Indians
# 179062     11415       2  Chennai Super Kings               Mumbai Indians
# 179063     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %% [markdown]
# Q12. Compute the average runs scored in matches in all the venues.

# %%
df3 = df2.merge(df, left_on='match_id', right_on='id')
df3.groupby('venue')['total_runs'].mean()

#I DON'T THINK IT IS THE RIGHT APPROACH
# Out:
# venue
# ACA-VDCA Stadium                                        1.340122
# Barabati Stadium                                        1.343953
# Brabourne Stadium                                       1.413019
# Buffalo Park                                            1.117483
# De Beers Diamond Oval                                   1.235537
# Dr DY Patil Sports Academy                              1.204608
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     1.225844
# Dubai International Cricket Stadium                     1.214118
# Eden Gardens                                            1.326052
# Feroz Shah Kotla                                        1.339144
# Feroz Shah Kotla Ground                                 1.328630
# Green Park                                              1.409338
# Himachal Pradesh Cricket Association Stadium            1.341825
# Holkar Cricket Stadium                                  1.486005
# ...

# %% [markdown]
# Q13. Find the umpires who umpired the maximum number of times.

# %%
# df.fillna("None") 
# df['umpire1'].value_counts() + df['umpire2'].value_counts() + df['umpire3'].value_counts() WHICH GAVE A WRONG ANSWER
# I WAS DOING THIS BUT LATER ASKED CHATGPT 

pd.concat([df['umpire1'], df['umpire2'], df['umpire3']]).value_counts()
# Out:
# S Ravi                     114
# HDPK Dharmasena             87
# C Shamshuddin               83
# AK Chaudhary                58
# SJA Taufel                  55
#                           ...
# Sundaram Ravi                2
# SD Ranade                    2
# Subroto Das                  1
# Nand Kishore                 1
# Chettithody Shamshuddin      1
# Length: 76, dtype: int64

# %% [markdown]
# Q14. Find the total number of matches played in each season.

# %%
df['season'].value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2018    60
# 2019    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %% [markdown]
# Q15. Find total runs scored in each season.

# %%
df3.groupby('season')['total_runs'].sum()
# Out:
# season
# 2008    17937
# 2009    16353
# 2010    18883
# 2011    21154
# 2012    22453
# 2013    22602
# 2014    18931
# 2015    18353
# 2016    18862
# 2017    18786
# 2018    20706
# 2019    20270
# Name: total_runs, dtype: int64

# %% [markdown]
# Q16. Calculate total number of runs scored by each batsman and display top 10.

# %%
df2.columns
df2.groupby('batsman')['total_runs'].sum()
# Out:
# batsman
# A Ashish Reddy     288
# A Chandila           4
# A Chopra            58
# A Choudhary         25
# A Dananjaya          4
#                   ...
# YV Takawale        207
# Yashpal Singh       49
# Younis Khan          3
# Yuvraj Singh      2895
# Z Khan             121
# Name: total_runs, Length: 516, dtype: int64

# %% [markdown]
# Q17. Compute the total number of wickets taken by each bowler.

# %% [markdown]
# Q18. Compute batting averages and display top 10.

# %% [markdown]
# Q19. Visualize toss decisions across all seasons.

# %%
df.groupby("season")['toss_decision'].value_counts().unstack().plot(kind='bar')
plt.xlabel("Season")
plt.ylabel("Count")
plt.title("Toss Decision by Season")
# Out:
# Text(0.5, 1.0, 'Toss Decision by Season')

# %% [markdown]
# Q20. Visualize Total Matches vs Winning Matches vs Win Rate for all teams.

# %% [markdown]
# Q21. Find the distribution of the teams who won the matches.

# %%
df['winner'].value_counts().plot(kind='bar')
plt.xlabel('Winner')
plt.ylabel('Number of wins')
plt.title("Distribution of winning teams")
# Out:
# Text(0.5, 1.0, 'Distribution of winning teams')

# %% [markdown]
# Q22. Visualize the toss outcomes of all teams.

# %%
df.groupby(['toss_winner'])['toss_decision'].value_counts().unstack().plot(kind='bar')
# Out:
# <Axes: xlabel='toss_winner'>

# %% [markdown]
# Q23. Visualize the top 5 teams with the most wins across all seasons.

# %%
df['winner'].value_counts().head().plot(kind='pie', autopct='%0.1f%%')
plt.xlabel('')
plt.ylabel('')
plt.title('Top 5 Team with most wins')
# Out:
# Text(0.5, 1.0, 'Top 5 Team with most wins')
