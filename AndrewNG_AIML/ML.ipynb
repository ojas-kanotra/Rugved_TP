# %% [markdown]
# # MACHINE LEARNING
#
# ---

# %% [markdown]
# > Supervised Learning:
#
# - Machine Learns from examples being supplied
# - The right answers that it gets
# - It predicts based on the supplied data
# - `Regression` is part of this type of learning method
# - Another supervised learning algorithm is `Classification Problem`
# - In classification problem learning algorithm has to fit a boundary line to the problem

# %% [markdown]
# > Unsupervised Learning:
#
# - In its `Clustering Algirithm` we find something interesting in unlebelled data
# - Data only comes with inputs x, but not output labels y.
# - Algorithm has to find structure in the data.
# - `Anomaly Detection` is used to find Unusual data points
# - `Dimensionality Reduction` Compress data using fewer number

# %% [markdown]
# > Regression Model:
#
# - **x:** Input variable (feature)
# - **y:** Output variable (target)
# - **m:** Number of training examples
#
# A regression model predicts a continuous value based on input features. It learns the relationship between x and y from the training data, aiming to minimize the difference between predicted and actual values.
#
# > Linear Model:
#
# - 1. **Model:** y = wx+b
# - 2. **Parameter:** w, b
# - 3. **Cost fxn:** To plot such a linear graph, we use the cost function. So, in our graph we have:
#     - ŷ which is the prediction
#     - y which is the data point
#     - ŷ-y is called the error where we are measuring our prediction and target vertical distance
#
#     `Squared Error Cost Function = 1/2m ∑(ŷ - y)²`
#
#     Since ŷ is our prediction value we can rewrite the cost function as
#
#     `Squared Error Cost Function = 1/2m ∑(f(x) - y)²`
#
# - 4. **Objective:** Since our cost function is of the form x²(when only w is the parameter and b is not present), it is in form of a parabola, where the actual value is the minima of parabolic equation.
#     - For functions with both the parameter w and b, the cost function has a shape more of like a soup boul.
#     - We can also flatten this into a contours graph, where the middlemost section will be minimum value.
#
#     - <img src="image.png" width="350"/>
#
# > Linear Regression Gradient Descent:
#
# Linear regression gradient descent is an optimization algorithm used to find the best-fit line for a set of data points by minimizing the cost function (usually Mean Squared Error).
#
# How it works:
#
# - The linear regression model predicts y = wx + b
# - The cost function measures how far the predictions are from the actual values.
# - Gradient descent iteratively updates the parameters w (weight) and b (bias) to reduce the cost:
#     - Compute the gradient (slope) of the cost function with respect to w and b.
#     - Update w and b in opposite direction to gradient
#         - w = w-alpha(dho J/ dho w)
#         - b = b-alpha(dho J/ dho b)
#     - This process repeats until the cost function reaches its minimum, meaning the model fits the data as well as possible.
# - <img src="image2.png" width="350"/>
#
# Note: An incorrect gradient descent algorithm updates the variable simultaneously however what shall be done is:
#
# ```py
#     tmp_w = w-alpha(dho J/ dho w)
#     tmp_b = b-alpha(dho J/ dho b)
#     w = tmp_w
#     b = tmp_b
# ```
#
# This is because both the derivatives should take the old value of w,b in the derivative of J hence we update the values later on, after finding the derivative.
#
# Simplifying the derivatives we get:
#
# ```py
#     tmp_w = w-alpha(1/m ∑(f(x) - y)x)
#     tmp_b = b-alpha(1/m ∑(f(x) - y))
#     w = tmp_w
#     b = tmp_b
# ```
#
# > Multiple features instead of one:
#
# Now if we have multiple features instead of \(x\), the equation is:
#
# $f_{w,b}(\vec{x}) = w_1 x_1 + w_2 x_2 + \cdots + w_n x_n + b$
#
# Or, in vector form:
#
# $f_{w,b}(\vec{x}) = \vec{w} \cdot \vec{x} + b$
#
# where
#
# $\vec{w} = [w_1, w_2, \ldots, w_n] \quad$
# $\vec{x} = [x_1, x_2, \ldots, x_n]$

# %%
import pandas as pd
import numpy as np

def m_print(text):
    print('\033[92m' + "\n" + text + '\033[0m')

data = pd.read_csv("co2.csv")
df = pd.DataFrame(data)
m_print("Original Database: ")
display(df.head())

m_print("Original Data Types: ")
print(df.dtypes)

# Some columns are text so we need to make them into integer :>
def conv_integer(datacolumn):
    global df
    indexing = {}
    if (df[datacolumn].dtype not in ['int64', 'float64', 'int32', 'float32']):
        indexing = dict(enumerate(list(set(df[datacolumn]))))
        value_to_int = {}
        for k, v in indexing.items():
            value_to_int[v] = k
        # value_to_int = {v: k for k, v in indexing.items()}
        df[datacolumn] = df[datacolumn].map(value_to_int)
        return indexing
    else:
        return
    
m_print("The indexing is: ")
print(np.array(list(map(conv_integer, list(df.columns)))))

m_print("Modified Data Types: ")
print(df.dtypes)

# Now let's try and run this 
m_print("Modified Database: ")
display(df.head())

# We are taking y as CO2 and all other independent variables are x'es
x = np.array(df[df.columns[0:-1]])
y = np.array(df[df.columns[-1]])

# Now we just added a new column of constant 1 to the matrix  
x = np.insert(x, 0, 1, axis=1)

# Now we take the coeffecient matrix 
# By formula our B = (X⊤X)¯¹X⊤Y

b = np.linalg.inv(np.dot(x.T, x)).dot(x.T).dot(y)

# y = b0 + b1x1 + b2x2.....
# Since testing data is normal.. we use this

m_print("Final testing with a row from original dataset: ")
m_print("Prediction Result: \t\tOriginal Data Result:")
for i in range(10):
    x_testing = df.iloc[i][:-1]
    y_prediction = b[0] + np.dot(x_testing, b[1:])

    print(y_prediction, end="\t\t")
    print(df.iloc[i, -1])
# Out:
# Original Database:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# 2                              5.8                               5.9
# 3                              9.1                              11.1
# 4                              8.7                              10.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196
# 1                           29                  221
# 2                           48                  136
# 3                           25                  255
# 4                           27                  244
# Original Data Types:
# Make                                 object
# Model                                object
# Vehicle Class                        object
# Engine Size(L)                      float64
# Cylinders                             int64
# Transmission                         object
# Fuel Type                            object
# Fuel Consumption City (L/100 km)    float64
# Fuel Consumption Hwy (L/100 km)     float64
# Fuel Consumption Comb (L/100 km)    float64
# Fuel Consumption Comb (mpg)           int64
# CO2 Emissions(g/km)                   int64
# dtype: object
#
# The indexing is:
# [{0: 'ROLLS-ROYCE', 1: 'AUDI', 2: 'MERCEDES-BENZ', 3: 'VOLVO', 4: 'FORD', 5: 'LINCOLN', 6: 'ACURA', 7: 'VOLKSWAGEN', 8: 'LEXUS', 9: 'CHRYSLER', 10: 'SCION', 11: 'ASTON MARTIN', 12: 'KIA', 13: 'LAMBORGHINI', 14: 'RAM', 15: 'HYUNDAI', 16: 'SUBARU', 17: 'BUGATTI', 18: 'JAGUAR', 19: 'PORSCHE', 20: 'CHEVROLET', 21: 'MITSUBISHI', 22: 'NISSAN', 23: 'BENTLEY', 24: 'HONDA', 25: 'MASERATI', 26: 'CADILLAC', 27: 'DODGE', 28: 'BUICK', 29: 'MINI', 30: 'MAZDA', 31: 'TOYOTA', 32: 'GMC', 33: 'INFINITI', 34: 'ALFA ROMEO', 35: 'SRT', 36: 'LAND ROVER', 37: 'GENESIS', 38: 'BMW', 39: 'SMART', 40: 'JEEP', 41: 'FIAT'}
#  {0: 'QUATTROPORTE S', 1: 'LaCrosse AWD', 2: 'S 550 4MATIC CABRIOLET', 3: '650i xDRIVE GRAN COUPE', 4: 'X1 xDRIVE35i', 5: 'Encore', 6: 'Giulia AWD', 7: 'Mustang (Performance Pkg)', 8: 'COROLLA iM', 9: 'Z4 sDRIVE28i', 10: 'EXPRESS 1500 PASSENGER', 11: '4RUNNER 4WD', 12: '200 SEDAN', 13: 'RX 450h AWD', 14: 'Versa', 15: 'F-TYPE S COUPE', 16: 'Ghost EWB', 17: 'FUSION (Start/Stop)', 18: 'X7 M50i', 19: 'F-TYPE V8 S CONVERTIBLE', 20: 'PRIUS v', 21: 'Colorado', 22: 'AMG C 43 4MATIC Cabriolet', 23: 'MKC AWD', 24: 'XT6 AWD', 25: 'FLEX', 26: 'CX-5 (SIL)', 27: 'E 350 CABRIOLET', 28: '500X', 29: 'Forte 5', 30: 'Acadia AWD', 31: 'BOXSTER SPYDER', 32: 'Taurus FFV AWD', 33: 'Enclave', 34: 'Pathfinder 4WD Platinum', 35: 'MAZDA6 (i-ELOOP)', 36: 'Colorado 4WD', 37: '911 Carrera 4', 38: '230i xDrive Cabriolet', 39: 'NSX', 40: 'M240i xDRIVE COUPE', 41: 'Cooper Convertible', 42: 'Cruze', 43: 'Panamera 4', 44: 'XF 20d AWD', 45: 'Compass 4X4', 46: 'WRANGLER 4X4', 47: 'CHALLENGER SRT DEMON', 48: 'Q3', 49: 'XT5 AWD', 50: 'Escalade 4WD', 51: '1500 ECODIESEL', 52: 'XC90 T5 AWD', 53: 'MDX SH-AWD', 54: 'RDX AWD A-SPEC', 55: 'Camry AWD XLE/XSE', 56: 'PANAMERA GTS', 57: 'LACROSSE eASSIST', 58: 'M5 SEDAN', 59: '435i xDRIVE CABRIOLET', 60: 'COOPER S 5 DOOR', 61: 'HIGHLANDER HYBRID AWD LE', 62: 'F-150 4X4 (Payload Pkg)', 63: 'AMG GL 63 S', 64: 'BEETLE CONVERTIBLE', 65: 'Highlander AWD LE', 66: '300 SRT (MDS)', 67: 'Sorento', 68: 'LS 600h L', 69: 'Panamera 4S ST', 70: 'M8 Cabriolet', 71: 'AMG CLA 45 4MATIC', 72: 'AMG E 63 S 4MATIC', 73: 'M760i xDRIVE', 74: 'CIVIC COUPE', 75: 'Corsair AWD', 76: 'Vantage V8', 77: 'Stinger AWD', 78: 'GLE 350d 4MATIC', 79: 'FLEX AWD (EcoBoost)', 80: 'X6 M50i', 81: '330i xDRIVE GRAN TURISMO', 82: 'Panamera 4 Executive', 83: 'QUATTROPORTE SQ4', 84: 'CRUZE', 85: '440i xDrive Cabriolet', 86: 'AMG C 63 S Coupe', 87: 'CL 550 4MATIC', 88: 'HR-V', 89: 'COOPER S COUPE', 90: 'TT ROADSTER QUATTRO', 91: 'COLORADO ZR2 4WD', 92: 'S4', 93: 'Levante Trofeo', 94: 'HIGHLANDER AWD', 95: 'TAURUS FFV', 96: 'F-TYPE Coupe', 97: '911 Targa 4S', 98: 'Encore GX', 99: 'Malibu', 100: 'RIO ECO', 101: 'Mazda3 5-Door (SIL)', 102: 'RANGE ROVER V8 5.0 SC FFV', 103: '911 Carrera GTS Cabriolet', 104: '535i xDRIVE GRAN TURISMO', 105: 'S60 T5', 106: 'Camaro ZL1', 107: 'Optima', 108: 'PACIFICA', 109: 'SOUL ECO Dynamics', 110: 'FORTWO CABRIOLET', 111: 'F-TYPE R AWD Coupe', 112: 'ENVISION AWD', 113: '228i COUPE', 114: 'XF 35t AWD', 115: 'OPTIMA FE', 116: 'Range Rover TD6 Diesel', 117: 'ROGUE AWD', 118: 'CAMARO Z/28', 119: 'PANAMERA', 120: 'XC60 3.0T AWD', 121: 'iQ', 122: 'Q70 AWD', 123: 'M8 Gran Coupe', 124: 'Q5', 125: 'AMG E 43 4MATIC', 126: 'AMG GLC 63 S 4MATIC+ Coupe', 127: 'COLORADO', 128: 'XTS', 129: '435i xDRIVE COUPE', 130: '440i xDRIVE COUPE', 131: 'SIERRA FFV', 132: 'M240i CABRIOLET', 133: 'AVENTADOR S COUPE', 134: 'DBS Superleggera', 135: 'Santa Fe XL Ultimate AWD', 136: 'PATHFINDER', 137: '440i xDrive Gran Coupe', 138: 'CAYMAN GT4', 139: 'A5 Cabriolet quattro', 140: 'FUSION', 141: 'GL 350 BLUETEC 4MATIC', 142: '550i xDRIVE SEDAN', 143: 'AMG GT 63 S 4MATIC+ Coupe', 144: '540i xDRIVE', 145: 'MKT AWD', 146: 'GX 460', 147: 'MUSTANG CONVERTIBLE', 148: 'ESCALADE ESV 4WD', 149: 'C 300 4MATIC Wagon', 150: '500 ABARTH', 151: 'Levante', 152: 'GLA 250 4MATIC', 153: 'ELANTRA', 154: 'XC60 T6', 155: 'MKZ', 156: 'AMG GT COUPE', 157: 'Range Rover Velar P250', 158: '320i xDRIVE', 159: 'R8 QUATTRO', 160: 'Camaro', 161: 'ENCORE SPORT TOURING', 162: 'Santa Fe XL AWD', 163: 'S60 POLESTAR AWD', 164: 'C 300 4MATIC COUPE', 165: 'Expedition MAX 4X4', 166: 'Challenger SRT Hellcat Widebody', 167: 'MACAN', 168: 'Cherokee 4X4 Active Drive Lock', 169: 'Wraith', 170: 'XKR CONVERTIBLE', 171: 'GHOST EWB', 172: 'F-150 RAPTOR 4WD', 173: 'TRAX AWD', 174: 'EXPLORER FFV', 175: 'Q60 AWD RED SPORT', 176: 'V8 VANTAGE', 177: 'SQ5 QUATTRO', 178: 'E 550 CABRIOLET', 179: 'ENCORE (LUV Engine)', 180: 'Outback AWD', 181: 'M3 SEDAN', 182: 'Tacoma 4WD D-Cab TRD Off-Road/Pro', 183: 'Ghibli', 184: 'S80 T6 AWD',  ...
#  {0: 'FULL-SIZE', 1: 'STATION WAGON - MID-SIZE', 2: 'COMPACT', 3: 'MID-SIZE', 4: 'SUBCOMPACT', 5: 'SUV - STANDARD', 6: 'STATION WAGON - SMALL', 7: 'SPECIAL PURPOSE VEHICLE', 8: 'PICKUP TRUCK - SMALL', 9: 'SUV - SMALL', 10: 'VAN - PASSENGER', 11: 'PICKUP TRUCK - STANDARD', 12: 'VAN - CARGO', 13: 'TWO-SEATER', 14: 'MINICOMPACT', 15: 'MINIVAN'}
#  None None
#  {0: 'AS8', 1: 'AV7', 2: 'AM5', 3: 'AS5', 4: 'AS4', 5: 'AS6', 6: 'AM6', 7: 'AS10', 8: 'M5', 9: 'AS7', 10: 'M6', 11: 'AM8', 12: 'A6', 13: 'AM9', 14: 'A8', 15: 'AM7', 16: 'A5', 17: 'AV8', 18: 'A9', 19: 'AV6', 20: 'AV10', 21: 'M7', 22: 'AS9', 23: 'A7', 24: 'A10', 25: 'A4', 26: 'AV'}
#  {0: 'N', 1: 'X', 2: 'D', 3: 'Z', 4: 'E'} None None None None None]
#
# Modified Data Types:
# Make                                  int64
# Model                                 int64
# Vehicle Class                         int64
# Engine Size(L)                      float64
# Cylinders                             int64
# Transmission                          int64
# Fuel Type                             int64
# Fuel Consumption City (L/100 km)    float64
# Fuel Consumption Hwy (L/100 km)     float64
# Fuel Consumption Comb (L/100 km)    float64
# Fuel Consumption Comb (mpg)           int64
# CO2 Emissions(g/km)                   int64
# dtype: object
#
# Modified Database:
#    Make  Model  Vehicle Class  Engine Size(L)  Cylinders  Transmission  \
# 0     6    899              2             2.0          4             3
# 1     6    899              2             2.4          4            10
# 2     6    661              2             1.5          4             1
# 3     6   1100              9             3.5          6             5
# 4     6   1740              9             3.5          6             5
#
#    Fuel Type  Fuel Consumption City (L/100 km)  \
# 0          3                               9.9
# 1          3                              11.2
# 2          3                               6.0
# 3          3                              12.7
# 4          3                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# 2                              5.8                               5.9
# 3                              9.1                              11.1
# 4                              8.7                              10.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196
# 1                           29                  221
# 2                           48                  136
# 3                           25                  255
# 4                           27                  244
# Final testing with a row from original dataset:
#
# Prediction Result: 		Original Data Result:
# 192.17394786012304		196
# 212.5143254017914		221
# 127.93124029177272		136
# 259.18372340766416		255
# 248.37634844354764		244
# 238.84840125963362		230
# 239.68435326821054		232
# 257.41875592322043		255
# 263.36695520874935		267
# 204.40913562153003		212
